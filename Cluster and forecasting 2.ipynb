# %%
##FOR R1 TO R12 PLOT TIME SERIES USE TIME STAMP TEMPERATURE AND 
##CLUSTER THE R1 TO R12 INTO 5 CLIUSTERS

# %%
import pandas as pd

# Replace "path/to/file.xlsx" with the actual path to your file
df = pd.read_excel("D:\Kevin Joshi\cons_data_all_res(1).xlsx")

# %%
df.head()
# Out:
#                  Time  year  moy_date  doy_date  busday  season  dow_date  \
# 0 2017-01-01 00:00:00  2017         1         1   False  Winter         1
# 1 2017-01-01 01:00:00  2017         1         1   False  Winter         1
# 2 2017-01-01 02:00:00  2017         1         1   False  Winter         1
# 3 2017-01-01 03:00:00  2017         1         1   False  Winter         1
# 4 2017-01-01 04:00:00  2017         1         1   False  Winter         1
#
#    hour month_name  temp  ...      r3      r4      r5      r6      r7      r8  \
# 0     0  January    22.0  ...  0.0821  0.0667  0.2131  0.0854  0.1277  0.2173
# 1     1  January    22.0  ...  0.0989  0.1047  0.1719  0.0948  0.1112  0.2411
# 2     2  January    22.0  ...  0.0990  0.1001  0.1865  0.0978  0.1850  0.8316
# 3     3  January    23.5  ...  0.1038  0.1354  0.1882  0.1064  0.0970  0.6645
# 4     4  January    27.0  ...  0.0780  0.3508  0.2092  0.2456  0.1374  1.9451
#
#        r9     r10     r11     r12
# ...

# %%
import matplotlib.pyplot as plt



for i in range(1, 13):
    plt.plot(df['Time'], df[f"r{i}"], label=f"Rainfall {i}")

plt.plot(df['Time'], df['temp'], label="Temperature")


plt.xlabel('Time')
plt.ylabel('Temperature/Rainfall')

plt.legend()


plt.show()

# %%
from sklearn.cluster import KMeans
rainfall = df.loc[:, 'r1':'r12']
kmeans = KMeans(n_clusters=5)
kmeans.fit(rainfall)
labels = kmeans.labels_
df['cluster'] = labels
print(df['cluster'].value_counts())
# Out:
# 1    4344
# 2    1920
# 4    1158
# 0     765
# 3     573
# Name: cluster, dtype: int64

# %%
df.head()
# Out:
#                  Time  year  moy_date  doy_date  busday  season  dow_date  \
# 0 2017-01-01 00:00:00  2017         1         1   False  Winter         1
# 1 2017-01-01 01:00:00  2017         1         1   False  Winter         1
# 2 2017-01-01 02:00:00  2017         1         1   False  Winter         1
# 3 2017-01-01 03:00:00  2017         1         1   False  Winter         1
# 4 2017-01-01 04:00:00  2017         1         1   False  Winter         1
#
#    hour month_name  temp  ...      r4      r5      r6      r7      r8      r9  \
# 0     0  January    22.0  ...  0.0667  0.2131  0.0854  0.1277  0.2173  0.1478
# 1     1  January    22.0  ...  0.1047  0.1719  0.0948  0.1112  0.2411  0.1597
# 2     2  January    22.0  ...  0.1001  0.1865  0.0978  0.1850  0.8316  0.2118
# 3     3  January    23.5  ...  0.1354  0.1882  0.1064  0.0970  0.6645  0.2361
# 4     4  January    27.0  ...  0.3508  0.2092  0.2456  0.1374  1.9451  0.3902
#
#       r10     r11     r12  cluster
# ...
